# %% [markdown]
# <a href="https://colab.research.google.com/github/chsachin799/100-days-of-ML/blob/main/39_Multivariate_Imputation_KNN_Imputer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('train.csv')[['Age','Pclass','Fare','Survived']]

# %%
df.head()
# Out:
#     Age  Pclass     Fare  Survived
# 0  22.0       3   7.2500         0
# 1  38.0       1  71.2833         1
# 2  26.0       3   7.9250         1
# 3  35.0       1  53.1000         1
# 4  35.0       3   8.0500         0

# %%
df.isnull().mean()*100
# Out:
# Age         19.86532
# Pclass       0.00000
# Fare         0.00000
# Survived     0.00000
# dtype: float64

# %%
x = df.drop(columns=['Survived'])
y = df['Survived']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
knn = KNNImputer(n_neighbors=4) # can also be used as weights='distance'
x_train_trf = knn.fit_transform(x_train)
x_test_trf = knn.transform(x_test)

# %%
pd.DataFrame(x_train_trf,columns=x_train.columns)
# Out:
#       Age  Pclass      Fare
# 0    45.5     1.0   28.5000
# 1    23.0     2.0   13.0000
# 2    32.0     3.0    7.9250
# 3    26.0     3.0    7.8542
# 4     6.0     3.0   31.2750
# ..    ...     ...       ...
# 707  21.0     3.0    7.6500
# 708  41.5     1.0   31.0000
# 709  41.0     3.0   14.1083
# 710  14.0     1.0  120.0000
# 711  21.0     1.0   77.2875
#
# [712 rows x 3 columns]

# %%
lr = LogisticRegression()

lr.fit(x_train_trf,y_train)
y_pred = lr.predict(x_test_trf)
accuracy_score(y_pred,y_test)
# Out:
# 0.7430167597765364

# %%
#comparison with simple imputer

si = SimpleImputer()
x_train_trf2 = si.fit_transform(x_train)
x_test_trf2 = si.transform(x_test)

# %%
lr  = LogisticRegression()
lr.fit(x_train_trf2,y_train)
y_pred = lr.predict(x_test_trf2)
accuracy_score(y_pred,y_test)
# Out:
# 0.7374301675977654
