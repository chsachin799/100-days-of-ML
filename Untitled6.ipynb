# %% [markdown]
# <a href="https://colab.research.google.com/github/chsachin799/100-days-of-ML/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
date = pd.read_csv('orders.csv')
time = pd.read_csv('messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# # working with date

# %%
#convert date from object (string) to datetime
date['date'] = pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %% [markdown]
# **1.Extract Year**

# %%
date['date_year']  = date['date'].dt.year

# %%
date['date_month_no'] = date['date'].dt.month

# %%
date['date_month_name'] = date['date'].dt.month_name()

# %% [markdown]
# **2.Extract Days**

# %%
date['date_day'] = date['date'].dt.day

# %%
date['date_dow'] = date['date'].dt.day_of_week

# %%
date['date_dow_name'] = date['date'].dt.day_name()
date.drop(columns =['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month  date_month_no date_month_name  date_day  \
# 0 2019-12-10       2019          12             12        December        10
# 1 2018-08-15       2018           8              8          August        15
# 2 2018-10-23       2018          10             10         October        23
# 3 2019-08-17       2019           8              8          August        17
# 4 2019-01-06       2019           1              1         January         6
#
#    date_dow date_dow_name
# 0         1       Tuesday
# 1         2     Wednesday
# 2         1       Tuesday
# 3         5      Saturday
# 4         6        Sunday

# %%
#is weekend?
date['date_is_weekend'] = np.where(date['date_dow_name'].isin(['Sunday','Saturday']),1,0)
date.drop(columns =['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month  date_month_no date_month_name  date_day  \
# 0 2019-12-10       2019          12             12        December        10
# 1 2018-08-15       2018           8              8          August        15
# 2 2018-10-23       2018          10             10         October        23
# 3 2019-08-17       2019           8              8          August        17
# 4 2019-01-06       2019           1              1         January         6
#
#    date_dow date_dow_name  date_is_weekend
# 0         1       Tuesday                0
# 1         2     Wednesday                0
# 2         1       Tuesday                0
# 3         5      Saturday                1
# 4         6        Sunday                1

# %% [markdown]
# **Extract week of the year**

# %%
date['date_week'] = date['date'].dt.weekday
date.drop(columns =['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month  date_month_no date_month_name  date_day  \
# 0 2019-12-10       2019          12             12        December        10
# 1 2018-08-15       2018           8              8          August        15
# 2 2018-10-23       2018          10             10         October        23
# 3 2019-08-17       2019           8              8          August        17
# 4 2019-01-06       2019           1              1         January         6
#
#    date_dow date_dow_name  date_is_weekend  date_week
# 0         1       Tuesday                0          1
# 1         2     Wednesday                0          2
# 2         1       Tuesday                0          1
# 3         5      Saturday                1          5
# 4         6        Sunday                1          6

# %% [markdown]
# **extract time elapsed between two dates**

# %%
import datetime
today = datetime.datetime.today()
today
# Out:
# datetime.datetime(2026, 1, 5, 19, 9, 17, 237305)

# %%
today - date['date']
# Out:
# 0     2218 days 19:09:17.237305
# 1     2700 days 19:09:17.237305
# 2     2631 days 19:09:17.237305
# 3     2333 days 19:09:17.237305
# 4     2556 days 19:09:17.237305
#                  ...
# 995   2646 days 19:09:17.237305
# 996   2587 days 19:09:17.237305
# 997   2435 days 19:09:17.237305
# 998   2500 days 19:09:17.237305
# 999   2274 days 19:09:17.237305
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today - date['date']).dt.days
# Out:
# 0      2218
# 1      2700
# 2      2631
# 3      2333
# 4      2556
#        ...
# 995    2646
# 996    2587
# 997    2435
# 998    2500
# 999    2274
# Name: date, Length: 1000, dtype: int64

# %% [markdown]
# # Time

# %%
time['date'] = pd.to_datetime(time['date'])

# %%
time['hour']=time['date'].dt.hour
# also dt.minute, dt.second
